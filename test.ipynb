# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./result_csv/data_0_12000.csv")
df
# Out:
#         idx                                              title  \
# 0         0                                          강아지 복부 팽만
# 1         1                                       강아지 슬개골탈구 수술
# 2         2                                  @Exception_alert@
# 3         3  포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요 근데 보기에...
# 4         4                                            강아지 치은종
# ...     ...                                                ...
# 11993  1412        저희개가 다른개에게 물렸습니다. 급하게 내일 광견병 예방접종을 하려고 하는데요
# 11994  1413                                  @Exception_alert@
# 11995  1414                                            강아지 검은변
# 11996  1415                                  @Exception_alert@
# 11997  1416                               강아지 발바닥 습진에관해서 질문이요!
#
#                                                 question  \
# 0      사진처럼 다리나 얼굴 목 쪽에는 살이 안쪘는데\n복부만 저렇게 불룩나와서 걱정되네요...
# 1      강아지가 다리 절어가지고 갔는데 슬개골 탈구일 확률이 90%인데요. 염증 치료제?를...
# ...

# %%
df[df['title']=='@Exception_alert@'].iloc[0,4]
# Out:
# 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80511&docId=443181173\n'

# %%
df[df['title']=='@Exception_alert@'].iloc[1,4]
# Out:
# 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80511&docId=443073603\n'

# %%
alert_url = df[df['title']=='@Exception_alert@']['url']

f = open("./result_csv/alert_url.txt", "a", encoding='utf-8')
for i in alert_url:
    f.write(i)
f.close()
# Out:
# <function TextIOWrapper.close()>

# %%
df2 = pd.read_csv("./result_csv/alert_data.csv")
df2
# Out:
#        idx                                              title  \
# 0        0                           강아지가 자다 일어나면 뒷다리 힘을 못써요.
# 1        1                                강아지 배안에 울퉁불퉁한게 만져져요
# 2        2                                         고양이가 토를 해요
# 3        3                                  강아지 수염쪽에 이상한게 낫어요
# 4        4  아까 세 시간 전쯤에 저희집 고양이(3살 남)가 실을 먹었는데 엄청 길었었어요 ㅠㅠ...
# ...    ...                                                ...
# 3954  3954                                       강아지 배부분 이상증상
# 3955  3955                                  @Exception_alert@
# 3956  3956  2년이란 시간을 함께한 레브라도 리트리버 주리가 무지개다리를 건넜어요. 어떻게 슬프...
# 3957  3957                                        중성화 사혜부 전적출
# 3958  3958                                  @Exception_alert@
#
#                                                question  \
# 0     저희 웰시코기가 4살인데 하루 3번산책을 하려고 노력하고 있습니다.\n15kg(남,...
# 1     그림그린거 처럼 만져지구요\n저부위에 무슨장기가 있는지\n아님 문제가 있는건지\n전...
# ...

# %%
df2[df2['title']=="@Exception_alert@"]
# Out:
#        idx              title question answer  \
# 5        5  @Exception_alert@      NaN    NaN
# 14      14  @Exception_alert@      NaN    NaN
# 16      16  @Exception_alert@      NaN    NaN
# 21      21  @Exception_alert@      NaN    NaN
# 26      26  @Exception_alert@      NaN    NaN
# ...    ...                ...      ...    ...
# 3948  3948  @Exception_alert@      NaN    NaN
# 3950  3950  @Exception_alert@      NaN    NaN
# 3952  3952  @Exception_alert@      NaN    NaN
# 3955  3955  @Exception_alert@      NaN    NaN
# 3958  3958  @Exception_alert@      NaN    NaN
#
#                                                     url
# 5     https://kin.naver.com/qna/detail.naver?d1id=8&...
# 14    https://kin.naver.com/qna/detail.naver?d1id=8&...
# 16    https://kin.naver.com/qna/detail.naver?d1id=8&...
# 21    https://kin.naver.com/qna/detail.naver?d1id=8&...
# 26    https://kin.naver.com/qna/detail.naver?d1id=8&...
# ...                                                 ...
# ...

# %%
alert_url2 = df2[df2['title']=='@Exception_alert@']['url']

f = open("./result_csv/alert_url_2.txt", "a", encoding='utf-8')
for i in alert_url2:
    f.write(i)
f.close()

# %%
not_alert = pd.concat([df[df['title']!='@Exception_alert@'],df2[df2['title']!='@Exception_alert@']])
not_alert
# Out:
#        idx                                              title  \
# 0        0                                          강아지 복부 팽만
# 1        1                                       강아지 슬개골탈구 수술
# 3        3  포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요 근데 보기에...
# 4        4                                            강아지 치은종
# 5        5            안녕하세요 저희가 키우는 강아지 팔에 이런게 생겼는데 이거 무엇인가요?
# ...    ...                                                ...
# 3951  3951                 강아지가 움직여서 눈을 찌르고 있는 털을 못자르는데 어떻하죠?
# 3953  3953                         15살 정도 개가 부추볶음을 먹었어요 괜찮나요.
# 3954  3954                                       강아지 배부분 이상증상
# 3956  3956  2년이란 시간을 함께한 레브라도 리트리버 주리가 무지개다리를 건넜어요. 어떻게 슬프...
# 3957  3957                                        중성화 사혜부 전적출
#
#                                                question  \
# 0     사진처럼 다리나 얼굴 목 쪽에는 살이 안쪘는데\n복부만 저렇게 불룩나와서 걱정되네요...
# 1     강아지가 다리 절어가지고 갔는데 슬개골 탈구일 확률이 90%인데요. 염증 치료제?를...
# ...

# %%
df3 = pd.read_csv("./result_csv/alert_data_2.csv")
df3
# Out:
#        idx                                              title  \
# 0        0  고양이 얼굴에 이런 게 났는데 왜 이런 건가요? 떼줄려고 해도 안 떼지고 혹처럼 붙...
# 1        1                             고양이 옆구리에 이런게 생겼는데(피부병)
# 2        2                                          강아지 목 피부병
# 3        3  강아지 항문 옆에 조그만한 뾰루지가 났습니다 ㅠㅠ 만져봤을때 조금 단단합니다. 혹시...
# 4        4  강아지 팔에 뭐가 났어요 약 일주일 전 강아지 팔에서 상처를 발견했습니다 미용할 때...
# ...    ...                                                ...
# 1870  1870                        강아지가 갑자기 이상한데 혹시 디스크 증상인가요?
# 1871  1871               강아지 턱이 살짝 빨개요ㅠㅠ\n원래 그런가요?\n발진일까요..??
# 1872  1872  간식자주주는 길고양이가 어제는 괜찮앗는데 오늘 보니 다리가 붓고 절면서 다가왓어요 ...
# 1873  1873                                           중성화와 표피염
# 1874  1874                           강아지가 생리하는 건지 발정기인지 모르겠어요
#
#                                                question  \
# 0     고양이 얼굴에 이런 게 났는데 왜 이런 건가요? 떼줄려고 해도 안 떼지고 혹처럼 붙...
# 1     고양이 옆구리에 이런게 생겼는데\n이것이 무엇일까요?ㅠㅠ\n그냥 둬도 되는지 혹은 ...
# ...

# %%
result = pd.concat([not_alert, df3])
result
# Out:
#        idx                                              title  \
# 0        0                                          강아지 복부 팽만
# 1        1                                       강아지 슬개골탈구 수술
# 3        3  포메라니안 키우고있는데 어제 병원갔다가 슬개골탈구 3기 진단을 받았어요 근데 보기에...
# 4        4                                            강아지 치은종
# 5        5            안녕하세요 저희가 키우는 강아지 팔에 이런게 생겼는데 이거 무엇인가요?
# ...    ...                                                ...
# 1870  1870                        강아지가 갑자기 이상한데 혹시 디스크 증상인가요?
# 1871  1871               강아지 턱이 살짝 빨개요ㅠㅠ\n원래 그런가요?\n발진일까요..??
# 1872  1872  간식자주주는 길고양이가 어제는 괜찮앗는데 오늘 보니 다리가 붓고 절면서 다가왓어요 ...
# 1873  1873                                           중성화와 표피염
# 1874  1874                           강아지가 생리하는 건지 발정기인지 모르겠어요
#
#                                                question  \
# 0     사진처럼 다리나 얼굴 목 쪽에는 살이 안쪘는데\n복부만 저렇게 불룩나와서 걱정되네요...
# 1     강아지가 다리 절어가지고 갔는데 슬개골 탈구일 확률이 90%인데요. 염증 치료제?를...
# ...

# %%
result.to_csv("./result_csv/result_0_12000.csv")
