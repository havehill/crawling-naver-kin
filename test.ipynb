# %%
# required to install selenium, bs4 
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time

import openpyxl
from openpyxl.styles import PatternFill, Color
from openpyxl import Workbook
from random import *

import pandas as pd

# %%
f = open("./result/url_list_2023-04-06_16:14:43_889417.txt",'r')
urls = f.readlines()

# %%
df = pd.read_excel("/Users/JAE111/crawling/result/2023-04-10_13:50:42_412159_crawling_result.xlsx")
df
# Out:
#                                       제목  \
# 0                         강아지 몸에 종기가 났어요
# 1                      앵무새 발톱이ㅜㅜ꺾인 거 같은데
# 2                            앵무새 날개 상처..
# 3                갓 5개월 된 아기 강아지 말티즈 사람음식
# 4                    강아지눈에 피인가요 충혈인가요ㅜㅠㅠ
# ..                                   ...
# 349                강아지 사람이 먹는 우유먹어도 될까요?
# 350                               고양이 설사
# 351  강아지가 저번달에교배를햇는데\n\n교배가된건가요? 한달정도됏어요
# 352                 포메리안은 털이 잘 빠지는 편인가요?
# 353                     고양이 블루베리 먹어도 되나요
#
#                                                     질문  \
# 0    강아지 몸에 혹? 또는 종기같은게 났어요 ㅠㅠ\n왜이런거죠? 토이푸들이고 나이는 1...
# 1    앵무새 발이 보통 횟대에 서있을 때 발가락 두 개는 앞에 있고 나머지 두 개는 뒤에...
# 2                       자해인지 병인지 알려주시고\n대처 방법좀 알려주세요..
# 3       저희 강아지가 사람 음식 먹고도 설사나 구토를 안 해요.. 나중에라도 탈 날까요..
# 4    단체로 실내에서 신발을 벽 쪽에 벗어두고 뭔가를 했다끝나고 신발을 신으려는데 신발이...
# ..                                                 ...
# 349                                        @Exception@
# ...

# %%
df.tail(10)
# Out:
#                                                     제목  \
# 344                                    말티즈 뒷다리 질문드립니다.
# 345  강아지 똥좀 봐주세요\n\n\n강아지가 똥을 쌌는데 이거 무슨 피 같기도 하고 피묻...
# 346                            여자아이 생리하기전 중성화하는것이 좋은가요
# 347  오늘아침에 갑자기 토하더라구요.\n오늘전까진 코숏이고 매우건강한 상태입니다(<-피검...
# 348              강아지가 토하고 열나고 떨고 움직이지도 않아요\n어떻게 해야하져 ?
# 349                              강아지 사람이 먹는 우유먹어도 될까요?
# 350                                             고양이 설사
# 351                강아지가 저번달에교배를햇는데\n\n교배가된건가요? 한달정도됏어요
# 352                               포메리안은 털이 잘 빠지는 편인가요?
# 353                                   고양이 블루베리 먹어도 되나요
#
#                                                     질문  \
# 344  저희 강아지가 뒷다리가 불편해서 날씨도 좋은데 산책을 못 시켜주고 있어요.\n뒷다리...
# 345                                        @Exception@
# 346                                        @Exception@
# 347                                        @Exception@
# 348                                        @Exception@
# ...

# %% [markdown]
# 비공개 : https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80511&docId=331901949
# https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80511&docId=331913413
